# %%
from langchain_community.utilities.sql_database import SQLDatabase

# %%
db = SQLDatabase.from_uri(f"mysql+pymysql://admin:4gnrfyR392mNvW3@testdb.c9eybgwfcpse.ap-south-1.rds.amazonaws.com/db")
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File ~/anaconda3/envs/tf215_p310/lib/python3.10/site-packages/pymysql/connections.py:649, in Connection.connect(self, sock)
#     648 try:
# --> 649     sock = socket.create_connection(
#     650         (self.host, self.port), self.connect_timeout, **kwargs
#     651     )
#     652     break
#
# File ~/anaconda3/envs/tf215_p310/lib/python3.10/socket.py:845, in create_connection(address, timeout, source_address)
#     844 try:
# --> 845     raise err
#     846 finally:
#     847     # Break explicitly a reference cycle
#
# File ~/anaconda3/envs/tf215_p310/lib/python3.10/socket.py:833, in create_connection(address, timeout, source_address)
#     832     sock.bind(source_address)
# --> 833 sock.connect(sa)
#     834 # Break explicitly a reference cycle
#
# TimeoutError: timed out
#
# ...
